% %% [markdown]
% # Single-subject Modelling in SPM
% In the final section of this lesson, we will see how to specify a single-subject GLM using `SPM12`. These models are also known as *1st-level* models, for reasons we will cover later in the module. The example data for this section consists of a fully pre-processed [functional scan](https://livemanchesterac.sharepoint.com/:u:/r/sites/UOM-FBMH-MSc-NCCN/Shared%20Documents/PCHN62121%20Image%20Analysis/Learning%20Materials/Asynchronous/Week%2008/2.%20Single-subject%20Models/Data/swRD018_PP012_Encoding.nii?csf=1&web=0&e=Xa6YSE&download=1) with associated [timing information](https://livemanchesterac.sharepoint.com/:x:/r/sites/UOM-FBMH-MSc-NCCN/Shared%20Documents/PCHN62121%20Image%20Analysis/Learning%20Materials/Asynchronous/Week%2008/2.%20Single-subject%20Models/Data/Timings.xlsx?d=w643a1e9e9efc44768b132bed48c4b00d&csf=1&web=0&e=tFu9G8&download=1).
%
% ## Example Experiment
% The example experiment is a simple block design that involved viewing pictures of different valences. Each block consisted of 6 pictures from the same valence category and the blocks were arranged as illustrated in {numref}`ex-design-fig`.
%
% ```{figure} images/example-design.png
% ---
% width: 600px
% name: ex-design-fig
% ---
% Schematic of the example experimental design.
% ```
%
% Examples of images shown during the *positive* block are given in {numref}`pos-ex-fig`
%
% ```{figure} images/pos-block-example.png
% ---
% width: 800px
% name: pos-ex-fig
% ---
% Example images from the *positive* valence block.
% ```
%
% Examples of images shown during the *negative* block are given in {numref}`neg-ex-fig`
%
% ```{figure} images/neg-block-example.png
% ---
% width: 800px
% name: neg-ex-fig
% ---
% Example images from the *negative* valence block.
% ```
%
% Examples of images shown during the *neutral* block are given in {numref}`neu-ex-fig`
%
% ```{figure} images/neu-block-example.png
% ---
% width: 800px
% name: neu-ex-fig
% ---
% Example images from the *neutral* valence block.
% ```
%
% Between each repetition of *positive*, *negative* and *neutral* blocks, the subjects were asked to rest for 15 seconds. During this time, they saw a fixation cross on the screen. This turned into a double-cross 5 seconds before the end of the rest period, as illustrated in {numref}`fix-ex-fig`.
%
% ```{figure} images/fix-block-example.png
% ---
% width: 800px
% name: fix-ex-fig
% ---
% Example of the fixation cross and double-cross displayed during the rest periods..
% ```
%
% In terms of the scanning details, the TR was 2s, the TE was 30ms and the voxel size was 3mm isotropic. 145 volumes were collected of dimensions $53 \times 63 \times 52$. The data has already been preprocessed by realignment to the first volume, normalisation to MNI space and Gaussian smoothing using a kernel of 8mm FWHM.
%
% ## Modelling Approach
% In terms of the modelling approach, a simple on-off dummy variable can be specified for each valence condition. These variables can then be convolved with the canonical HRF. Importantly, we will choose to include the rest periods as an *implicit baseline*. This means we will not model rest explicitly. Instead, rest will form the *constant* or *baseline* condition. As explained earlier, this means the parameter estimates will be interpreted as *mean differences*, representing the average signal change from rest for each experimental condition.
%
% ## Specifying a Single-subject Model in SPM
% The video below will guide you through the process of specifying a single-subject GLM using SPM.
%
% <div style="max-width: 1280px"><div style="position: relative; padding-bottom: 56.25%; height: 0; overflow: hidden;"><iframe src="https://livemanchesterac.sharepoint.com/sites/UOM-FBMH-MSc-NCCN/_layouts/15/embed.aspx?UniqueId=1852fc3c-b43d-4e07-b9bf-7a231b65d879&embed=%7B%22hvm%22%3Atrue%2C%22ust%22%3Atrue%7D&referrer=StreamWebApp&referrerScenario=EmbedDialog.Create" width="1280" height="720" frameborder="0" scrolling="no" allowfullscreen title="SingleSubjectSPM.mov" style="border:none; position: absolute; top: 0; left: 0; right: 0; bottom: 0; height: 100%; max-width: 100%;"></iframe></div></div>
